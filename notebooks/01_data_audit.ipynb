# %%
# 01_data_audit.ipynb - Nassau Candy Route Efficiency Project
# Critical: Real datasets have quality issues. This notebook discovers them.

import pandas as pd
import numpy as np
from src.data_loader import load_raw_data
from src.config import US_REGIONS, DATE_FORMAT
import matplotlib.pyplot as plt
import seaborn as sns

print("🔍 STEP 3: DATA AUDIT - Discovering real-world data quality issues")

# Load data
df = load_raw_data()
print(f"📊 Dataset shape: {df.shape}")
print(f"📋 Columns: {list(df.columns)}")
# Out:
# C:\Users\riyan\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 from src.data_loader import load_raw_data
#       7 from src.config import US_REGIONS, DATE_FORMAT
#       8 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'src'

# %%
# Cell 1: Direct Load + Basic Audit (Fixed)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("🔍 STEP 3: DATA AUDIT - Discovering real-world data quality issues")

# Load raw CSV directly from attachments
df = pd.read_csv(r"C:\Users\riyan\OneDrive\Attachments\Documents\nassau_shipping_route_efficiency\data\raw\Nassau Candy Distributor.csv")  # Your uploaded file
print(f"📊 Dataset shape: {df.shape}")
print(f"📋 Columns ({len(df.columns)}): {list(df.columns)}")
print("\n📄 First 3 rows:")
print(df.head(3).to_string())
print("\n📈 Data types:")
print(df.dtypes)
# Out:
# 🔍 STEP 3: DATA AUDIT - Discovering real-world data quality issues
# 📊 Dataset shape: (10194, 18)
# 📋 Columns (18): ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Country/Region', 'City', 'State/Province', 'Postal Code', 'Division', 'Region', 'Product ID', 'Product Name', 'Sales', 'Units', 'Gross Profit', 'Cost']
#
# 📄 First 3 rows:
#    Row ID                      Order ID  Order Date   Ship Date       Ship Mode  Customer ID Country/Region        City State/Province Postal Code   Division    Region     Product ID                       Product Name  Sales  Units  Gross Profit  Cost
# 0       1  US-2021-103800-CHO-MIL-31000  03-01-2024  30-06-2026  Standard Class       103800  United States     Houston          Texas       77095  Chocolate  Interior  CHO-MIL-31000         Wonka Bar - Milk Chocolate   6.50      2          4.22  2.28
# ...
